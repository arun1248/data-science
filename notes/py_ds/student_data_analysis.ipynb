# %% [markdown]
# pip install pyarrow matplotlib

# %%
import pandas as pd

# %%
data = {
    'Hours_Studied': [2, 4, 6, 8, 10],
    'Test_Score': [50, 60, 70, 60, 90]
}
df = pd.DataFrame(data)

# %%
df.corr()
# Out:
#                Hours_Studied  Test_Score
# Hours_Studied       1.000000    0.834058
# Test_Score          0.834058    1.000000

# %%
data = {
    'Hours_Studied': [2, 4, 6, 8, 10],  # Kept the same for consistency
    'Test_Score': [55, 65, 68, 85, 88],  # Less linear: scores don't increase as uniformly
    'Study_Breaks': [4, 2, 3, 1, 2],     # More varied breaks, not strictly decreasing
    'Sleep_Hours': [6, 7, 6.5, 8, 7.5]  # More sleep with more study hours
}
df = pd.DataFrame(data)

# %%
df.corr()
# Out:
#                Hours_Studied  Test_Score  Study_Breaks  Sleep_Hours
# Hours_Studied       1.000000    0.974508     -0.693375     0.800000
# Test_Score          0.974508    1.000000     -0.807697     0.906519
# Study_Breaks       -0.693375   -0.807697      1.000000    -0.970725
# Sleep_Hours         0.800000    0.906519     -0.970725     1.000000

# %%
df = pd.read_csv('student-mat.csv', sep=';')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
(df.dtypes == 'int64').sum()
# Out:
# np.int64(16)

# %%
df.corr(numeric_only=True).count().sum()
# Out:
# np.int64(256)

# %%
(df
 .corr(numeric_only=True)
 .style
 .background_gradient()
)
# Out:
# <style type="text/css">
# #T_04bc1_row0_col0, #T_04bc1_row1_col1, #T_04bc1_row2_col2, #T_04bc1_row3_col3, #T_04bc1_row4_col4, #T_04bc1_row5_col5, #T_04bc1_row6_col6, #T_04bc1_row7_col7, #T_04bc1_row8_col8, #T_04bc1_row9_col9, #T_04bc1_row10_col10, #T_04bc1_row11_col11, #T_04bc1_row12_col12, #T_04bc1_row13_col13, #T_04bc1_row14_col14, #T_04bc1_row15_col15 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_04bc1_row0_col1, #T_04bc1_row4_col3, #T_04bc1_row5_col6, #T_04bc1_row12_col6, #T_04bc1_row12_col11 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_04bc1_row0_col2, #T_04bc1_row13_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_04bc1_row0_col3, #T_04bc1_row5_col7 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_04bc1_row0_col4, #T_04bc1_row6_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_04bc1_row0_col5 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# ...

# %%
(df
 .corr(numeric_only=True)
 .style
 .background_gradient(cmap='RdBu')
)
# Out:
# <style type="text/css">
# #T_49bec_row0_col0, #T_49bec_row1_col1, #T_49bec_row2_col2, #T_49bec_row3_col3, #T_49bec_row4_col4, #T_49bec_row5_col5, #T_49bec_row6_col6, #T_49bec_row7_col7, #T_49bec_row8_col8, #T_49bec_row9_col9, #T_49bec_row10_col10, #T_49bec_row11_col11, #T_49bec_row12_col12, #T_49bec_row13_col13, #T_49bec_row14_col14, #T_49bec_row15_col15 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_49bec_row0_col1, #T_49bec_row4_col3, #T_49bec_row5_col6, #T_49bec_row12_col6, #T_49bec_row12_col11 {
#   background-color: #930e26;
#   color: #f1f1f1;
# }
# #T_49bec_row0_col2, #T_49bec_row13_col3 {
#   background-color: #991027;
#   color: #f1f1f1;
# }
# #T_49bec_row0_col3, #T_49bec_row5_col7 {
#   background-color: #d7634f;
#   color: #f1f1f1;
# }
# #T_49bec_row0_col4, #T_49bec_row6_col2 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_49bec_row0_col5 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# ...

# %%
(df
 .corr(numeric_only=True)
 .style
 .background_gradient('RdBu', vmin= -1, vmax= 1)
)
# Out:
# <style type="text/css">
# #T_9ce87_row0_col0, #T_9ce87_row1_col1, #T_9ce87_row2_col2, #T_9ce87_row3_col3, #T_9ce87_row4_col4, #T_9ce87_row5_col5, #T_9ce87_row6_col6, #T_9ce87_row7_col7, #T_9ce87_row8_col8, #T_9ce87_row9_col9, #T_9ce87_row10_col10, #T_9ce87_row11_col11, #T_9ce87_row12_col12, #T_9ce87_row13_col13, #T_9ce87_row14_col14, #T_9ce87_row15_col15 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_9ce87_row0_col1, #T_9ce87_row0_col2, #T_9ce87_row0_col15, #T_9ce87_row1_col0, #T_9ce87_row2_col0, #T_9ce87_row2_col3, #T_9ce87_row3_col2, #T_9ce87_row8_col14, #T_9ce87_row14_col8, #T_9ce87_row15_col0 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_9ce87_row0_col3, #T_9ce87_row3_col0, #T_9ce87_row7_col11, #T_9ce87_row9_col11, #T_9ce87_row11_col7, #T_9ce87_row11_col9 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_9ce87_row0_col4, #T_9ce87_row1_col6, #T_9ce87_row2_col6, #T_9ce87_row4_col0, #T_9ce87_row6_col1, #T_9ce87_row6_col2 {
# ...

# %%
from scipy.stats import pointbiserialr
df['sex_binary'] = df['sex'].map({'F':0, 'M':1})
#df.corr(numeric_only=True)
pointbiserialr(df['sex_binary'], df['G1'])
# Out:
# SignificanceResult(statistic=np.float64(0.09183915929290792), pvalue=np.float64(0.06825227168840918))

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...
