# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_points = np.random.random(10) * 100
y_points = np.random.random(10) * 100

plt.scatter(x_points, y_points)
plt.scatter(y_points, x_points)
x_points, y_points
# Out:
# (array([47.94308399, 18.86252217, 16.05789293, 67.04412744, 42.33138122,
#         51.27253838, 35.33379261, 43.88578993, 54.89915102, 42.78649767]),
#  array([ 0.47363324, 50.18183272, 44.69049697, 16.0398973 , 99.14742217,
#         12.60277983, 35.56702841, 43.94115294, 66.56830914, 97.70310053]))

# %% [markdown]
# ### ?
# is possible to specify steps or range between like 0-10 instead of 0-20
